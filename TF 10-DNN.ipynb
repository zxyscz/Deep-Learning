# %%
from tensorflow.examples.tutorials.mnist import input_data

mnist = input_data.read_data_sets("/tmp/data/")
# Out:
# Successfully downloaded train-images-idx3-ubyte.gz 9912422 bytes.
# Extracting /tmp/data/train-images-idx3-ubyte.gz
# Successfully downloaded train-labels-idx1-ubyte.gz 28881 bytes.
# Extracting /tmp/data/train-labels-idx1-ubyte.gz
# Successfully downloaded t10k-images-idx3-ubyte.gz 1648877 bytes.
# Extracting /tmp/data/t10k-images-idx3-ubyte.gz
# Successfully downloaded t10k-labels-idx1-ubyte.gz 4542 bytes.
# Extracting /tmp/data/t10k-labels-idx1-ubyte.gz

# %%
X_train = mnist.train.images
X_test = mnist.test.images
y_train = mnist.train.labels.astype("int")
y_test = mnist.test.labels.astype("int")

# %%
import tensorflow as tf

config = tf.contrib.learn.RunConfig(tf_random_seed=42) # not shown in the config

feature_cols = tf.contrib.learn.infer_real_valued_columns_from_input(X_train)
dnn_clf = tf.contrib.learn.DNNClassifier(hidden_units=[300,100], n_classes=10,
                                         feature_columns=feature_cols, config=config)
dnn_clf = tf.contrib.learn.SKCompat(dnn_clf) # if TensorFlow >= 1.1
dnn_clf.fit(X_train, y_train, batch_size=50, steps=40000)
# Out:
# WARNING:tensorflow:Using temporary folder as model directory: /var/folders/59/0pbnsns93t5cgn8b5n2kpxt00000gn/T/tmpc_4b1195
# INFO:tensorflow:Using config: {'_task_type': None, '_task_id': 0, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x11fb9c278>, '_master': '', '_num_ps_replicas': 0, '_num_worker_replicas': 0, '_environment': 'local', '_is_chief': True, '_evaluation_master': '', '_tf_config': gpu_options {
#   per_process_gpu_memory_fraction: 1
# }
# , '_tf_random_seed': 42, '_save_summary_steps': 100, '_save_checkpoints_secs': 600, '_session_config': None, '_save_checkpoints_steps': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_model_dir': '/var/folders/59/0pbnsns93t5cgn8b5n2kpxt00000gn/T/tmpc_4b1195'}
# WARNING:tensorflow:From /Users/ling/anaconda3/envs/tensorflow/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/estimators/head.py:625: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into /var/folders/59/0pbnsns93t5cgn8b5n2kpxt00000gn/T/tmpc_4b1195/model.ckpt.
# INFO:tensorflow:loss = 2.36404, step = 1
# INFO:tensorflow:global_step/sec: 250.297
# INFO:tensorflow:loss = 0.309677, step = 101 (0.402 sec)
# INFO:tensorflow:global_step/sec: 235.265
# INFO:tensorflow:loss = 0.254103, step = 201 (0.424 sec)
# INFO:tensorflow:global_step/sec: 230.067
# INFO:tensorflow:loss = 0.403251, step = 301 (0.435 sec)
# INFO:tensorflow:global_step/sec: 227.152
# INFO:tensorflow:loss = 0.248612, step = 401 (0.440 sec)
# INFO:tensorflow:global_step/sec: 224.97
# INFO:tensorflow:loss = 0.238972, step = 501 (0.444 sec)
# INFO:tensorflow:global_step/sec: 239.586
# INFO:tensorflow:loss = 0.0964612, step = 601 (0.417 sec)
# INFO:tensorflow:global_step/sec: 219.182
# INFO:tensorflow:loss = 0.119384, step = 701 (0.458 sec)
# INFO:tensorflow:global_step/sec: 191.281
# INFO:tensorflow:loss = 0.184879, step = 801 (0.523 sec)
# INFO:tensorflow:global_step/sec: 187.473
# INFO:tensorflow:loss = 0.093465, step = 901 (0.531 sec)
# INFO:tensorflow:global_step/sec: 185.462
# INFO:tensorflow:loss = 0.206881, step = 1001 (0.542 sec)
# INFO:tensorflow:global_step/sec: 167.88
# INFO:tensorflow:loss = 0.187316, step = 1101 (0.598 sec)
# INFO:tensorflow:global_step/sec: 158.734
# INFO:tensorflow:loss = 0.1543, step = 1201 (0.625 sec)
# INFO:tensorflow:global_step/sec: 165.891
# INFO:tensorflow:loss = 0.163595, step = 1301 (0.603 sec)
# INFO:tensorflow:global_step/sec: 159.068
# INFO:tensorflow:loss = 0.0720562, step = 1401 (0.630 sec)
# INFO:tensorflow:global_step/sec: 182.354
# INFO:tensorflow:loss = 0.0723128, step = 1501 (0.549 sec)
# INFO:tensorflow:global_step/sec: 216.886
# INFO:tensorflow:loss = 0.121916, step = 1601 (0.459 sec)
# INFO:tensorflow:global_step/sec: 230.206
# INFO:tensorflow:loss = 0.039761, step = 1701 (0.443 sec)
# INFO:tensorflow:global_step/sec: 212.839
# INFO:tensorflow:loss = 0.152173, step = 1801 (0.462 sec)
# INFO:tensorflow:global_step/sec: 221.094
# INFO:tensorflow:loss = 0.070405, step = 1901 (0.452 sec)
# INFO:tensorflow:global_step/sec: 205.935
# INFO:tensorflow:loss = 0.0662507, step = 2001 (0.486 sec)
# INFO:tensorflow:global_step/sec: 214.407
# INFO:tensorflow:loss = 0.0241838, step = 2101 (0.466 sec)
# INFO:tensorflow:global_step/sec: 231.603
# INFO:tensorflow:loss = 0.0292274, step = 2201 (0.432 sec)
# INFO:tensorflow:global_step/sec: 219.643
# INFO:tensorflow:loss = 0.0513423, step = 2301 (0.456 sec)
# INFO:tensorflow:global_step/sec: 246.17
# INFO:tensorflow:loss = 0.0555448, step = 2401 (0.405 sec)
# INFO:tensorflow:global_step/sec: 233.704
# INFO:tensorflow:loss = 0.0884138, step = 2501 (0.429 sec)
# INFO:tensorflow:global_step/sec: 203.536
# INFO:tensorflow:loss = 0.0315207, step = 2601 (0.491 sec)
# INFO:tensorflow:global_step/sec: 203.637
# INFO:tensorflow:loss = 0.0126636, step = 2701 (0.490 sec)
# INFO:tensorflow:global_step/sec: 219.957
# INFO:tensorflow:loss = 0.0514662, step = 2801 (0.455 sec)
# INFO:tensorflow:global_step/sec: 208.993
# INFO:tensorflow:loss = 0.088122, step = 2901 (0.479 sec)
# INFO:tensorflow:global_step/sec: 202.398
# INFO:tensorflow:loss = 0.0138777, step = 3001 (0.494 sec)
# INFO:tensorflow:global_step/sec: 238.697
# INFO:tensorflow:loss = 0.044173, step = 3101 (0.419 sec)
# INFO:tensorflow:global_step/sec: 226.347
# INFO:tensorflow:loss = 0.0120668, step = 3201 (0.443 sec)
# INFO:tensorflow:global_step/sec: 230.75
# INFO:tensorflow:loss = 0.0452911, step = 3301 (0.434 sec)
# INFO:tensorflow:global_step/sec: 229.422
# INFO:tensorflow:loss = 0.152817, step = 3401 (0.435 sec)
# INFO:tensorflow:global_step/sec: 224.428
# INFO:tensorflow:loss = 0.0838171, step = 3501 (0.445 sec)
# INFO:tensorflow:global_step/sec: 227.76
# INFO:tensorflow:loss = 0.156769, step = 3601 (0.440 sec)
# INFO:tensorflow:global_step/sec: 226.692
# INFO:tensorflow:loss = 0.0343551, step = 3701 (0.441 sec)
# INFO:tensorflow:global_step/sec: 233.541
# INFO:tensorflow:loss = 0.00878235, step = 3801 (0.428 sec)
# INFO:tensorflow:global_step/sec: 242.069
# INFO:tensorflow:loss = 0.152629, step = 3901 (0.413 sec)
# INFO:tensorflow:global_step/sec: 226.266
# INFO:tensorflow:loss = 0.0950618, step = 4001 (0.442 sec)
# INFO:tensorflow:global_step/sec: 220.696
# INFO:tensorflow:loss = 0.0524628, step = 4101 (0.453 sec)
# INFO:tensorflow:global_step/sec: 228.223
# INFO:tensorflow:loss = 0.0629685, step = 4201 (0.438 sec)
# INFO:tensorflow:global_step/sec: 159.029
# INFO:tensorflow:loss = 0.166633, step = 4301 (0.629 sec)
# INFO:tensorflow:global_step/sec: 144.402
# INFO:tensorflow:loss = 0.108088, step = 4401 (0.696 sec)
# INFO:tensorflow:global_step/sec: 172.972
# INFO:tensorflow:loss = 0.0167887, step = 4501 (0.575 sec)
# INFO:tensorflow:global_step/sec: 143.324
# INFO:tensorflow:loss = 0.0170214, step = 4601 (0.698 sec)
# INFO:tensorflow:global_step/sec: 170.371
# INFO:tensorflow:loss = 0.00988497, step = 4701 (0.591 sec)
# INFO:tensorflow:global_step/sec: 167.588
# INFO:tensorflow:loss = 0.0218255, step = 4801 (0.592 sec)
# INFO:tensorflow:global_step/sec: 201.871
# INFO:tensorflow:loss = 0.0958064, step = 4901 (0.495 sec)
# INFO:tensorflow:global_step/sec: 200.055
# INFO:tensorflow:loss = 0.032898, step = 5001 (0.500 sec)
# INFO:tensorflow:global_step/sec: 205.06
# INFO:tensorflow:loss = 0.00692303, step = 5101 (0.487 sec)
# INFO:tensorflow:global_step/sec: 181.767
# INFO:tensorflow:loss = 0.0374796, step = 5201 (0.551 sec)
# INFO:tensorflow:global_step/sec: 223.823
# INFO:tensorflow:loss = 0.0408561, step = 5301 (0.446 sec)
# INFO:tensorflow:global_step/sec: 215.918
# INFO:tensorflow:loss = 0.0703828, step = 5401 (0.463 sec)
# INFO:tensorflow:global_step/sec: 202.154
# INFO:tensorflow:loss = 0.0597546, step = 5501 (0.496 sec)
# INFO:tensorflow:global_step/sec: 225.663
# INFO:tensorflow:loss = 0.0637175, step = 5601 (0.442 sec)
# INFO:tensorflow:global_step/sec: 243.561
# INFO:tensorflow:loss = 0.0142295, step = 5701 (0.411 sec)
# INFO:tensorflow:global_step/sec: 190.256
# INFO:tensorflow:loss = 0.008777, step = 5801 (0.526 sec)
# INFO:tensorflow:global_step/sec: 179.909
# INFO:tensorflow:loss = 0.0868253, step = 5901 (0.556 sec)
# INFO:tensorflow:global_step/sec: 172.375
# INFO:tensorflow:loss = 0.109432, step = 6001 (0.580 sec)
# INFO:tensorflow:global_step/sec: 146.884
# INFO:tensorflow:loss = 0.0131425, step = 6101 (0.680 sec)
# INFO:tensorflow:global_step/sec: 162.14
# INFO:tensorflow:loss = 0.0240843, step = 6201 (0.617 sec)
# INFO:tensorflow:global_step/sec: 197.857
# INFO:tensorflow:loss = 0.085723, step = 6301 (0.508 sec)
# INFO:tensorflow:global_step/sec: 186.242
# INFO:tensorflow:loss = 0.0259363, step = 6401 (0.537 sec)
# INFO:tensorflow:global_step/sec: 193.716
# INFO:tensorflow:loss = 0.00852303, step = 6501 (0.516 sec)
# INFO:tensorflow:global_step/sec: 212.712
# INFO:tensorflow:loss = 0.0227815, step = 6601 (0.467 sec)
# INFO:tensorflow:global_step/sec: 212.448
# INFO:tensorflow:loss = 0.0275877, step = 6701 (0.471 sec)
# INFO:tensorflow:global_step/sec: 244.718
# INFO:tensorflow:loss = 0.0085514, step = 6801 (0.409 sec)
# INFO:tensorflow:global_step/sec: 242.795
# INFO:tensorflow:loss = 0.0113093, step = 6901 (0.412 sec)
# INFO:tensorflow:global_step/sec: 259.298
# INFO:tensorflow:loss = 0.0190613, step = 7001 (0.386 sec)
# INFO:tensorflow:global_step/sec: 255.511
# INFO:tensorflow:loss = 0.00409009, step = 7101 (0.391 sec)
# INFO:tensorflow:global_step/sec: 215.162
# INFO:tensorflow:loss = 0.0582136, step = 7201 (0.465 sec)
# INFO:tensorflow:global_step/sec: 246.424
# INFO:tensorflow:loss = 0.00672715, step = 7301 (0.406 sec)
# INFO:tensorflow:global_step/sec: 226.025
# INFO:tensorflow:loss = 0.0127499, step = 7401 (0.443 sec)
# INFO:tensorflow:global_step/sec: 227.367
# INFO:tensorflow:loss = 0.005338, step = 7501 (0.439 sec)
# INFO:tensorflow:global_step/sec: 210.901
# INFO:tensorflow:loss = 0.0160609, step = 7601 (0.476 sec)
# INFO:tensorflow:global_step/sec: 208.965
# INFO:tensorflow:loss = 0.00499156, step = 7701 (0.478 sec)
# INFO:tensorflow:global_step/sec: 204.399
# INFO:tensorflow:loss = 0.00483353, step = 7801 (0.488 sec)
# INFO:tensorflow:global_step/sec: 238.697
# INFO:tensorflow:loss = 0.00696935, step = 7901 (0.419 sec)
# INFO:tensorflow:global_step/sec: 236.651
# INFO:tensorflow:loss = 0.00272221, step = 8001 (0.423 sec)
# INFO:tensorflow:global_step/sec: 237.148
# INFO:tensorflow:loss = 0.0217708, step = 8101 (0.421 sec)
# INFO:tensorflow:global_step/sec: 235.178
# INFO:tensorflow:loss = 0.0288787, step = 8201 (0.425 sec)
# INFO:tensorflow:global_step/sec: 246.421
# INFO:tensorflow:loss = 0.0539877, step = 8301 (0.405 sec)
# INFO:tensorflow:global_step/sec: 249.255
# INFO:tensorflow:loss = 0.00857862, step = 8401 (0.402 sec)
# INFO:tensorflow:global_step/sec: 255.756
# INFO:tensorflow:loss = 0.00668675, step = 8501 (0.391 sec)
# INFO:tensorflow:global_step/sec: 247.548
# INFO:tensorflow:loss = 0.00526417, step = 8601 (0.404 sec)
# INFO:tensorflow:global_step/sec: 247.083
# INFO:tensorflow:loss = 0.00431127, step = 8701 (0.405 sec)
# INFO:tensorflow:global_step/sec: 246.48
# INFO:tensorflow:loss = 0.00488374, step = 8801 (0.406 sec)
# INFO:tensorflow:global_step/sec: 251.684
# INFO:tensorflow:loss = 0.00250303, step = 8901 (0.397 sec)
# INFO:tensorflow:global_step/sec: 259.192
# INFO:tensorflow:loss = 0.0148685, step = 9001 (0.386 sec)
# INFO:tensorflow:global_step/sec: 248.037
# INFO:tensorflow:loss = 0.00912793, step = 9101 (0.403 sec)
# INFO:tensorflow:global_step/sec: 246.313
# INFO:tensorflow:loss = 0.00432368, step = 9201 (0.406 sec)
# INFO:tensorflow:global_step/sec: 234.533
# INFO:tensorflow:loss = 0.0138446, step = 9301 (0.427 sec)
# INFO:tensorflow:global_step/sec: 233.776
# INFO:tensorflow:loss = 0.0518277, step = 9401 (0.427 sec)
# INFO:tensorflow:global_step/sec: 216.998
# INFO:tensorflow:loss = 0.00607764, step = 9501 (0.461 sec)
# INFO:tensorflow:global_step/sec: 211.447
# INFO:tensorflow:loss = 0.0207135, step = 9601 (0.475 sec)
# INFO:tensorflow:global_step/sec: 234.574
# INFO:tensorflow:loss = 0.0166932, step = 9701 (0.424 sec)
# INFO:tensorflow:global_step/sec: 218.895
# INFO:tensorflow:loss = 0.00487015, step = 9801 (0.457 sec)
# INFO:tensorflow:global_step/sec: 247.76
# INFO:tensorflow:loss = 0.0185824, step = 9901 (0.403 sec)
# INFO:tensorflow:global_step/sec: 249.153
# INFO:tensorflow:loss = 0.0240925, step = 10001 (0.402 sec)
# INFO:tensorflow:global_step/sec: 247.537
# INFO:tensorflow:loss = 0.00462607, step = 10101 (0.405 sec)
# INFO:tensorflow:global_step/sec: 248.13
# INFO:tensorflow:loss = 0.0100708, step = 10201 (0.402 sec)
# INFO:tensorflow:global_step/sec: 248.818
# INFO:tensorflow:loss = 0.00573162, step = 10301 (0.402 sec)
# INFO:tensorflow:global_step/sec: 251.323
# INFO:tensorflow:loss = 0.0101062, step = 10401 (0.398 sec)
# INFO:tensorflow:global_step/sec: 250.509
# INFO:tensorflow:loss = 0.00470994, step = 10501 (0.399 sec)
# INFO:tensorflow:global_step/sec: 235.799
# INFO:tensorflow:loss = 0.00745281, step = 10601 (0.424 sec)
# INFO:tensorflow:global_step/sec: 247.414
# INFO:tensorflow:loss = 0.0220603, step = 10701 (0.404 sec)
# INFO:tensorflow:global_step/sec: 250.993
# INFO:tensorflow:loss = 0.0147888, step = 10801 (0.399 sec)
# INFO:tensorflow:global_step/sec: 250.674
# INFO:tensorflow:loss = 0.00258084, step = 10901 (0.399 sec)
# INFO:tensorflow:global_step/sec: 245.084
# INFO:tensorflow:loss = 0.0285976, step = 11001 (0.408 sec)
# INFO:tensorflow:global_step/sec: 246.013
# INFO:tensorflow:loss = 0.0044351, step = 11101 (0.407 sec)
# INFO:tensorflow:global_step/sec: 247.275
# INFO:tensorflow:loss = 0.00119579, step = 11201 (0.406 sec)
# INFO:tensorflow:global_step/sec: 229.023
# INFO:tensorflow:loss = 0.0158182, step = 11301 (0.435 sec)
# INFO:tensorflow:global_step/sec: 228.172
# INFO:tensorflow:loss = 0.00693267, step = 11401 (0.438 sec)
# INFO:tensorflow:global_step/sec: 232.32
# INFO:tensorflow:loss = 0.0174892, step = 11501 (0.431 sec)
# INFO:tensorflow:global_step/sec: 219.777
# INFO:tensorflow:loss = 0.000888462, step = 11601 (0.455 sec)
# INFO:tensorflow:global_step/sec: 232.339
# INFO:tensorflow:loss = 0.0026345, step = 11701 (0.430 sec)
# INFO:tensorflow:global_step/sec: 215.608
# INFO:tensorflow:loss = 0.000522998, step = 11801 (0.469 sec)
# INFO:tensorflow:global_step/sec: 216.793
# INFO:tensorflow:loss = 0.0101293, step = 11901 (0.457 sec)
# INFO:tensorflow:global_step/sec: 241.312
# INFO:tensorflow:loss = 0.000120309, step = 12001 (0.414 sec)
# INFO:tensorflow:global_step/sec: 187.033
# INFO:tensorflow:loss = 0.00283077, step = 12101 (0.535 sec)
# INFO:tensorflow:global_step/sec: 215.824
# INFO:tensorflow:loss = 0.00376223, step = 12201 (0.463 sec)
# INFO:tensorflow:global_step/sec: 233.496
# INFO:tensorflow:loss = 0.00516198, step = 12301 (0.428 sec)
# INFO:tensorflow:global_step/sec: 209.439
# INFO:tensorflow:loss = 0.000395552, step = 12401 (0.477 sec)
# INFO:tensorflow:global_step/sec: 231.306
# INFO:tensorflow:loss = 0.0038692, step = 12501 (0.432 sec)
# INFO:tensorflow:global_step/sec: 248.184
# INFO:tensorflow:loss = 0.000996494, step = 12601 (0.403 sec)
# INFO:tensorflow:global_step/sec: 248.434
# INFO:tensorflow:loss = 0.00522744, step = 12701 (0.403 sec)
# INFO:tensorflow:global_step/sec: 237.38
# INFO:tensorflow:loss = 0.00650308, step = 12801 (0.421 sec)
# INFO:tensorflow:global_step/sec: 248.76
# INFO:tensorflow:loss = 0.00290468, step = 12901 (0.402 sec)
# INFO:tensorflow:global_step/sec: 251.076
# INFO:tensorflow:loss = 0.00306313, step = 13001 (0.399 sec)
# INFO:tensorflow:global_step/sec: 223.83
# INFO:tensorflow:loss = 0.0040113, step = 13101 (0.448 sec)
# INFO:tensorflow:global_step/sec: 228.225
# INFO:tensorflow:loss = 0.00749846, step = 13201 (0.437 sec)
# INFO:tensorflow:global_step/sec: 173.781
# INFO:tensorflow:loss = 0.00422553, step = 13301 (0.581 sec)
# INFO:tensorflow:global_step/sec: 199.833
# INFO:tensorflow:loss = 0.00333589, step = 13401 (0.497 sec)
# INFO:tensorflow:global_step/sec: 210.147
# INFO:tensorflow:loss = 0.00930926, step = 13501 (0.473 sec)
# INFO:tensorflow:global_step/sec: 250.297
# INFO:tensorflow:loss = 0.00580592, step = 13601 (0.399 sec)
# INFO:tensorflow:global_step/sec: 246.603
# INFO:tensorflow:loss = 0.00158466, step = 13701 (0.406 sec)
# INFO:tensorflow:global_step/sec: 225.458
# INFO:tensorflow:loss = 0.00957848, step = 13801 (0.444 sec)
# INFO:tensorflow:global_step/sec: 234.177
# INFO:tensorflow:loss = 0.0029991, step = 13901 (0.427 sec)
# INFO:tensorflow:global_step/sec: 230.163
# INFO:tensorflow:loss = 0.00257565, step = 14001 (0.434 sec)
# INFO:tensorflow:global_step/sec: 238.21
# INFO:tensorflow:loss = 0.0051015, step = 14101 (0.420 sec)
# INFO:tensorflow:global_step/sec: 238.751
# INFO:tensorflow:loss = 0.00931561, step = 14201 (0.419 sec)
# INFO:tensorflow:global_step/sec: 232.099
# INFO:tensorflow:loss = 0.00167436, step = 14301 (0.432 sec)
# INFO:tensorflow:global_step/sec: 239.079
# INFO:tensorflow:loss = 0.00068472, step = 14401 (0.417 sec)
# INFO:tensorflow:global_step/sec: 236.342
# INFO:tensorflow:loss = 0.000823331, step = 14501 (0.424 sec)
# INFO:tensorflow:global_step/sec: 240.659
# INFO:tensorflow:loss = 0.00392992, step = 14601 (0.415 sec)
# INFO:tensorflow:global_step/sec: 229.673
# INFO:tensorflow:loss = 0.00197606, step = 14701 (0.435 sec)
# INFO:tensorflow:global_step/sec: 228.827
# INFO:tensorflow:loss = 0.00111108, step = 14801 (0.437 sec)
# INFO:tensorflow:global_step/sec: 221.675
# INFO:tensorflow:loss = 0.00252097, step = 14901 (0.453 sec)
# INFO:tensorflow:global_step/sec: 217.054
# INFO:tensorflow:loss = 0.000814515, step = 15001 (0.459 sec)
# INFO:tensorflow:global_step/sec: 197.167
# INFO:tensorflow:loss = 0.00237104, step = 15101 (0.509 sec)
# INFO:tensorflow:global_step/sec: 198.673
# INFO:tensorflow:loss = 0.00227502, step = 15201 (0.502 sec)
# INFO:tensorflow:global_step/sec: 241.278
# INFO:tensorflow:loss = 0.00141252, step = 15301 (0.414 sec)
# INFO:tensorflow:global_step/sec: 251.356
# INFO:tensorflow:loss = 0.00455337, step = 15401 (0.398 sec)
# INFO:tensorflow:global_step/sec: 251.923
# INFO:tensorflow:loss = 0.00491852, step = 15501 (0.397 sec)
# INFO:tensorflow:global_step/sec: 243.587
# INFO:tensorflow:loss = 0.00487903, step = 15601 (0.411 sec)
# INFO:tensorflow:global_step/sec: 241.987
# INFO:tensorflow:loss = 0.0134273, step = 15701 (0.414 sec)
# INFO:tensorflow:global_step/sec: 247.734
# INFO:tensorflow:loss = 0.00312125, step = 15801 (0.402 sec)
# INFO:tensorflow:global_step/sec: 239.09
# INFO:tensorflow:loss = 0.000708232, step = 15901 (0.419 sec)
# INFO:tensorflow:global_step/sec: 250.232
# INFO:tensorflow:loss = 0.00560298, step = 16001 (0.399 sec)
# INFO:tensorflow:global_step/sec: 239.762
# INFO:tensorflow:loss = 0.00430737, step = 16101 (0.417 sec)
# INFO:tensorflow:global_step/sec: 246.256
# INFO:tensorflow:loss = 7.45395e-05, step = 16201 (0.406 sec)
# INFO:tensorflow:global_step/sec: 255.677
# INFO:tensorflow:loss = 0.00280412, step = 16301 (0.391 sec)
# INFO:tensorflow:global_step/sec: 250.398
# INFO:tensorflow:loss = 0.001583, step = 16401 (0.399 sec)
# INFO:tensorflow:global_step/sec: 255.104
# INFO:tensorflow:loss = 0.00205469, step = 16501 (0.392 sec)
# INFO:tensorflow:global_step/sec: 247.055
# INFO:tensorflow:loss = 0.00472116, step = 16601 (0.405 sec)
# INFO:tensorflow:global_step/sec: 256.539
# INFO:tensorflow:loss = 0.00300912, step = 16701 (0.390 sec)
# INFO:tensorflow:global_step/sec: 237.684
# INFO:tensorflow:loss = 0.00221508, step = 16801 (0.422 sec)
# INFO:tensorflow:global_step/sec: 217.996
# INFO:tensorflow:loss = 0.00274078, step = 16901 (0.458 sec)
# INFO:tensorflow:global_step/sec: 232.841
# INFO:tensorflow:loss = 0.00335069, step = 17001 (0.430 sec)
# INFO:tensorflow:global_step/sec: 222.054
# INFO:tensorflow:loss = 0.000582267, step = 17101 (0.450 sec)
# INFO:tensorflow:global_step/sec: 220.021
# INFO:tensorflow:loss = 0.00259225, step = 17201 (0.455 sec)
# INFO:tensorflow:global_step/sec: 250.896
# INFO:tensorflow:loss = 0.000920891, step = 17301 (0.398 sec)
# INFO:tensorflow:global_step/sec: 257.914
# INFO:tensorflow:loss = 0.00217769, step = 17401 (0.388 sec)
# INFO:tensorflow:global_step/sec: 249.702
# INFO:tensorflow:loss = 0.00163418, step = 17501 (0.400 sec)
# INFO:tensorflow:global_step/sec: 246.05
# INFO:tensorflow:loss = 0.000338328, step = 17601 (0.407 sec)
# INFO:tensorflow:global_step/sec: 256.885
# INFO:tensorflow:loss = 0.000893746, step = 17701 (0.389 sec)
# INFO:tensorflow:global_step/sec: 252.807
# INFO:tensorflow:loss = 0.000348846, step = 17801 (0.396 sec)
# INFO:tensorflow:global_step/sec: 249.761
# INFO:tensorflow:loss = 0.00200284, step = 17901 (0.400 sec)
# INFO:tensorflow:global_step/sec: 241.846
# INFO:tensorflow:loss = 0.0012488, step = 18001 (0.415 sec)
# INFO:tensorflow:global_step/sec: 251.946
# INFO:tensorflow:loss = 0.00122258, step = 18101 (0.397 sec)
# INFO:tensorflow:global_step/sec: 251.607
# INFO:tensorflow:loss = 0.00400346, step = 18201 (0.396 sec)
# INFO:tensorflow:global_step/sec: 251.739
# INFO:tensorflow:loss = 0.0154516, step = 18301 (0.398 sec)
# INFO:tensorflow:global_step/sec: 260.481
# INFO:tensorflow:loss = 0.00357402, step = 18401 (0.382 sec)
# INFO:tensorflow:global_step/sec: 255.335
# INFO:tensorflow:loss = 0.00224499, step = 18501 (0.392 sec)
# INFO:tensorflow:global_step/sec: 251.612
# INFO:tensorflow:loss = 0.00348468, step = 18601 (0.397 sec)
# INFO:tensorflow:global_step/sec: 240.453
# INFO:tensorflow:loss = 0.00106254, step = 18701 (0.416 sec)
# INFO:tensorflow:global_step/sec: 231.982
# INFO:tensorflow:loss = 0.00134678, step = 18801 (0.431 sec)
# INFO:tensorflow:global_step/sec: 227.773
# INFO:tensorflow:loss = 0.00304573, step = 18901 (0.440 sec)
# INFO:tensorflow:global_step/sec: 216.517
# INFO:tensorflow:loss = 0.00137681, step = 19001 (0.461 sec)
# INFO:tensorflow:global_step/sec: 231.167
# INFO:tensorflow:loss = 0.000547609, step = 19101 (0.432 sec)
# INFO:tensorflow:global_step/sec: 246.811
# INFO:tensorflow:loss = 0.000463684, step = 19201 (0.405 sec)
# INFO:tensorflow:global_step/sec: 254.151
# INFO:tensorflow:loss = 0.00509027, step = 19301 (0.393 sec)
# INFO:tensorflow:global_step/sec: 253.698
# INFO:tensorflow:loss = 0.000722533, step = 19401 (0.394 sec)
# INFO:tensorflow:global_step/sec: 249.493
# INFO:tensorflow:loss = 0.00281473, step = 19501 (0.401 sec)
# INFO:tensorflow:global_step/sec: 252.395
# INFO:tensorflow:loss = 0.000629583, step = 19601 (0.396 sec)
# INFO:tensorflow:global_step/sec: 255.85
# INFO:tensorflow:loss = 0.000147449, step = 19701 (0.391 sec)
# INFO:tensorflow:global_step/sec: 241.321
# INFO:tensorflow:loss = 0.000430371, step = 19801 (0.415 sec)
# INFO:tensorflow:global_step/sec: 250.545
# INFO:tensorflow:loss = 0.00136521, step = 19901 (0.399 sec)
# INFO:tensorflow:global_step/sec: 253.283
# INFO:tensorflow:loss = 0.0024896, step = 20001 (0.395 sec)
# INFO:tensorflow:global_step/sec: 240.742
# INFO:tensorflow:loss = 0.000431558, step = 20101 (0.415 sec)
# INFO:tensorflow:global_step/sec: 253.823
# INFO:tensorflow:loss = 0.00192564, step = 20201 (0.394 sec)
# INFO:tensorflow:global_step/sec: 243.509
# INFO:tensorflow:loss = 0.000940824, step = 20301 (0.411 sec)
# INFO:tensorflow:global_step/sec: 241.263
# INFO:tensorflow:loss = 0.000245953, step = 20401 (0.414 sec)
# INFO:tensorflow:global_step/sec: 236.321
# INFO:tensorflow:loss = 0.00025361, step = 20501 (0.423 sec)
# INFO:tensorflow:global_step/sec: 233.83
# INFO:tensorflow:loss = 0.00130026, step = 20601 (0.428 sec)
# INFO:tensorflow:global_step/sec: 227.399
# INFO:tensorflow:loss = 0.00123567, step = 20701 (0.441 sec)
# INFO:tensorflow:global_step/sec: 231.621
# INFO:tensorflow:loss = 0.00204745, step = 20801 (0.431 sec)
# INFO:tensorflow:global_step/sec: 222.761
# INFO:tensorflow:loss = 0.00153957, step = 20901 (0.457 sec)
# INFO:tensorflow:global_step/sec: 147.769
# INFO:tensorflow:loss = 0.00241378, step = 21001 (0.668 sec)
# INFO:tensorflow:global_step/sec: 144.192
# INFO:tensorflow:loss = 0.00142351, step = 21101 (0.700 sec)
# INFO:tensorflow:global_step/sec: 158.12
# INFO:tensorflow:loss = 0.00256507, step = 21201 (0.629 sec)
# INFO:tensorflow:global_step/sec: 174.742
# INFO:tensorflow:loss = 0.00106203, step = 21301 (0.571 sec)
# INFO:tensorflow:global_step/sec: 165.684
# INFO:tensorflow:loss = 0.0025859, step = 21401 (0.603 sec)
# INFO:tensorflow:global_step/sec: 180.4
# INFO:tensorflow:loss = 0.000238369, step = 21501 (0.557 sec)
# INFO:tensorflow:global_step/sec: 157.987
# INFO:tensorflow:loss = 0.00158536, step = 21601 (0.631 sec)
# INFO:tensorflow:global_step/sec: 163.57
# INFO:tensorflow:loss = 0.000727434, step = 21701 (0.609 sec)
# INFO:tensorflow:global_step/sec: 170.203
# INFO:tensorflow:loss = 0.000661301, step = 21801 (0.590 sec)
# INFO:tensorflow:global_step/sec: 153.853
# INFO:tensorflow:loss = 0.000490357, step = 21901 (0.647 sec)
# INFO:tensorflow:global_step/sec: 174.796
# INFO:tensorflow:loss = 0.000124842, step = 22001 (0.573 sec)
# INFO:tensorflow:global_step/sec: 193.765
# INFO:tensorflow:loss = 0.000445235, step = 22101 (0.517 sec)
# INFO:tensorflow:global_step/sec: 165.775
# INFO:tensorflow:loss = 0.00133724, step = 22201 (0.603 sec)
# INFO:tensorflow:global_step/sec: 189.823
# INFO:tensorflow:loss = 0.00247763, step = 22301 (0.527 sec)
# INFO:tensorflow:global_step/sec: 202.128
# INFO:tensorflow:loss = 0.00171271, step = 22401 (0.494 sec)
# INFO:tensorflow:global_step/sec: 191.188
# INFO:tensorflow:loss = 0.00149307, step = 22501 (0.523 sec)
# INFO:tensorflow:global_step/sec: 235.621
# INFO:tensorflow:loss = 0.00392994, step = 22601 (0.424 sec)
# INFO:tensorflow:global_step/sec: 245.184
# INFO:tensorflow:loss = 0.000875101, step = 22701 (0.408 sec)
# INFO:tensorflow:global_step/sec: 239.422
# INFO:tensorflow:loss = 0.00118385, step = 22801 (0.418 sec)
# INFO:tensorflow:global_step/sec: 239.582
# INFO:tensorflow:loss = 0.00240292, step = 22901 (0.417 sec)
# INFO:tensorflow:global_step/sec: 252.821
# INFO:tensorflow:loss = 0.000830913, step = 23001 (0.396 sec)
# INFO:tensorflow:global_step/sec: 190.24
# INFO:tensorflow:loss = 0.00284528, step = 23101 (0.526 sec)
# INFO:tensorflow:global_step/sec: 193.266
# INFO:tensorflow:loss = 0.00224091, step = 23201 (0.517 sec)
# INFO:tensorflow:global_step/sec: 203.257
# INFO:tensorflow:loss = 0.00193402, step = 23301 (0.492 sec)
# INFO:tensorflow:global_step/sec: 203.242
# INFO:tensorflow:loss = 0.000599899, step = 23401 (0.491 sec)
# INFO:tensorflow:global_step/sec: 224.912
# INFO:tensorflow:loss = 0.000690191, step = 23501 (0.445 sec)
# INFO:tensorflow:global_step/sec: 245.18
# INFO:tensorflow:loss = 0.0006689, step = 23601 (0.408 sec)
# INFO:tensorflow:global_step/sec: 248.69
# INFO:tensorflow:loss = 0.000450027, step = 23701 (0.402 sec)
# INFO:tensorflow:global_step/sec: 253.475
# INFO:tensorflow:loss = 0.00181704, step = 23801 (0.394 sec)
# INFO:tensorflow:global_step/sec: 250.36
# INFO:tensorflow:loss = 0.00110625, step = 23901 (0.400 sec)
# INFO:tensorflow:global_step/sec: 240.27
# INFO:tensorflow:loss = 0.000971603, step = 24001 (0.416 sec)
# INFO:tensorflow:global_step/sec: 235.175
# INFO:tensorflow:loss = 0.000599703, step = 24101 (0.426 sec)
# INFO:tensorflow:global_step/sec: 237.218
# INFO:tensorflow:loss = 0.00103672, step = 24201 (0.421 sec)
# INFO:tensorflow:global_step/sec: 248.243
# INFO:tensorflow:loss = 0.000316926, step = 24301 (0.403 sec)
# INFO:tensorflow:global_step/sec: 230.957
# INFO:tensorflow:loss = 0.00197788, step = 24401 (0.432 sec)
# INFO:tensorflow:global_step/sec: 236.524
# INFO:tensorflow:loss = 0.000518455, step = 24501 (0.423 sec)
# INFO:tensorflow:global_step/sec: 218.934
# INFO:tensorflow:loss = 0.000293449, step = 24601 (0.457 sec)
# INFO:tensorflow:global_step/sec: 239.582
# INFO:tensorflow:loss = 0.00114909, step = 24701 (0.418 sec)
# INFO:tensorflow:global_step/sec: 233.257
# INFO:tensorflow:loss = 0.00152487, step = 24801 (0.428 sec)
# INFO:tensorflow:global_step/sec: 256.094
# INFO:tensorflow:loss = 0.00201351, step = 24901 (0.391 sec)
# INFO:tensorflow:global_step/sec: 255.666
# INFO:tensorflow:loss = 0.000152594, step = 25001 (0.391 sec)
# INFO:tensorflow:global_step/sec: 254.774
# INFO:tensorflow:loss = 0.00193388, step = 25101 (0.392 sec)
# INFO:tensorflow:global_step/sec: 253.276
# INFO:tensorflow:loss = 0.00282617, step = 25201 (0.395 sec)
# INFO:tensorflow:global_step/sec: 251.835
# INFO:tensorflow:loss = 0.000192127, step = 25301 (0.397 sec)
# INFO:tensorflow:global_step/sec: 255.723
# INFO:tensorflow:loss = 0.000797401, step = 25401 (0.391 sec)
# INFO:tensorflow:global_step/sec: 248.766
# INFO:tensorflow:loss = 0.00124578, step = 25501 (0.402 sec)
# INFO:tensorflow:global_step/sec: 260.417
# INFO:tensorflow:loss = 0.00119779, step = 25601 (0.384 sec)
# INFO:tensorflow:global_step/sec: 249.669
# INFO:tensorflow:loss = 0.000874612, step = 25701 (0.401 sec)
# INFO:tensorflow:global_step/sec: 244.287
# INFO:tensorflow:loss = 0.00136518, step = 25801 (0.410 sec)
# INFO:tensorflow:global_step/sec: 249.37
# INFO:tensorflow:loss = 0.00184243, step = 25901 (0.400 sec)
# INFO:tensorflow:global_step/sec: 240.52
# INFO:tensorflow:loss = 7.84672e-05, step = 26001 (0.416 sec)
# INFO:tensorflow:global_step/sec: 248.489
# INFO:tensorflow:loss = 0.00103029, step = 26101 (0.402 sec)
# INFO:tensorflow:global_step/sec: 247.473
# INFO:tensorflow:loss = 0.000715368, step = 26201 (0.404 sec)
# INFO:tensorflow:global_step/sec: 240.747
# INFO:tensorflow:loss = 0.000957418, step = 26301 (0.415 sec)
# INFO:tensorflow:global_step/sec: 221.714
# INFO:tensorflow:loss = 0.00165632, step = 26401 (0.451 sec)
# INFO:tensorflow:global_step/sec: 216.531
# INFO:tensorflow:loss = 0.00100959, step = 26501 (0.463 sec)
# INFO:tensorflow:global_step/sec: 243.425
# INFO:tensorflow:loss = 0.000594357, step = 26601 (0.409 sec)
# INFO:tensorflow:global_step/sec: 248.271
# INFO:tensorflow:loss = 3.75124e-05, step = 26701 (0.404 sec)
# INFO:tensorflow:global_step/sec: 233.579
# INFO:tensorflow:loss = 0.000775705, step = 26801 (0.427 sec)
# INFO:tensorflow:global_step/sec: 235.825
# INFO:tensorflow:loss = 0.000904265, step = 26901 (0.424 sec)
# INFO:tensorflow:global_step/sec: 249.862
# INFO:tensorflow:loss = 0.000553487, step = 27001 (0.400 sec)
# INFO:tensorflow:global_step/sec: 255.619
# INFO:tensorflow:loss = 0.00042911, step = 27101 (0.391 sec)
# INFO:tensorflow:global_step/sec: 250.317
# INFO:tensorflow:loss = 0.000641743, step = 27201 (0.400 sec)
# INFO:tensorflow:global_step/sec: 255.058
# INFO:tensorflow:loss = 0.00113445, step = 27301 (0.392 sec)
# INFO:tensorflow:global_step/sec: 252.56
# INFO:tensorflow:loss = 0.000147887, step = 27401 (0.396 sec)
# INFO:tensorflow:global_step/sec: 253.532
# INFO:tensorflow:loss = 0.00149474, step = 27501 (0.394 sec)
# INFO:tensorflow:global_step/sec: 249.014
# INFO:tensorflow:loss = 0.00099866, step = 27601 (0.401 sec)
# INFO:tensorflow:global_step/sec: 238.923
# INFO:tensorflow:loss = 0.000368925, step = 27701 (0.420 sec)
# INFO:tensorflow:global_step/sec: 230.702
# INFO:tensorflow:loss = 0.000700521, step = 27801 (0.432 sec)
# INFO:tensorflow:global_step/sec: 244.725
# INFO:tensorflow:loss = 0.000367836, step = 27901 (0.409 sec)
# INFO:tensorflow:global_step/sec: 236.71
# INFO:tensorflow:loss = 0.00131156, step = 28001 (0.422 sec)
# INFO:tensorflow:global_step/sec: 238.199
# INFO:tensorflow:loss = 0.000550622, step = 28101 (0.420 sec)
# INFO:tensorflow:global_step/sec: 242.34
# INFO:tensorflow:loss = 0.00143182, step = 28201 (0.412 sec)
# INFO:tensorflow:global_step/sec: 259.88
# INFO:tensorflow:loss = 0.000660615, step = 28301 (0.385 sec)
# INFO:tensorflow:global_step/sec: 240.602
# INFO:tensorflow:loss = 0.00102658, step = 28401 (0.418 sec)
# INFO:tensorflow:global_step/sec: 230.709
# INFO:tensorflow:loss = 0.000680939, step = 28501 (0.431 sec)
# INFO:tensorflow:global_step/sec: 230.092
# INFO:tensorflow:loss = 0.000403072, step = 28601 (0.435 sec)
# INFO:tensorflow:global_step/sec: 228.302
# INFO:tensorflow:loss = 0.000918623, step = 28701 (0.438 sec)
# INFO:tensorflow:global_step/sec: 233.603
# INFO:tensorflow:loss = 0.000993003, step = 28801 (0.429 sec)
# INFO:tensorflow:global_step/sec: 226.668
# INFO:tensorflow:loss = 0.000232585, step = 28901 (0.440 sec)
# INFO:tensorflow:global_step/sec: 233.764
# INFO:tensorflow:loss = 0.00192796, step = 29001 (0.428 sec)
# INFO:tensorflow:global_step/sec: 251.337
# INFO:tensorflow:loss = 0.00101591, step = 29101 (0.398 sec)
# INFO:tensorflow:global_step/sec: 256.221
# INFO:tensorflow:loss = 0.00169011, step = 29201 (0.390 sec)
# INFO:tensorflow:global_step/sec: 252.85
# INFO:tensorflow:loss = 0.00108807, step = 29301 (0.396 sec)
# INFO:tensorflow:global_step/sec: 251.23
# INFO:tensorflow:loss = 0.00101428, step = 29401 (0.398 sec)
# INFO:tensorflow:global_step/sec: 245.576
# INFO:tensorflow:loss = 0.000796202, step = 29501 (0.407 sec)
# INFO:tensorflow:global_step/sec: 243.635
# INFO:tensorflow:loss = 0.000337627, step = 29601 (0.411 sec)
# INFO:tensorflow:global_step/sec: 245.647
# INFO:tensorflow:loss = 0.000258813, step = 29701 (0.408 sec)
# INFO:tensorflow:global_step/sec: 241.706
# INFO:tensorflow:loss = 0.000616941, step = 29801 (0.412 sec)
# INFO:tensorflow:global_step/sec: 236.34
# INFO:tensorflow:loss = 0.00074321, step = 29901 (0.423 sec)
# INFO:tensorflow:global_step/sec: 224.583
# INFO:tensorflow:loss = 6.01432e-05, step = 30001 (0.446 sec)
# INFO:tensorflow:global_step/sec: 238.426
# INFO:tensorflow:loss = 0.000580716, step = 30101 (0.419 sec)
# INFO:tensorflow:global_step/sec: 245.207
# INFO:tensorflow:loss = 0.000218506, step = 30201 (0.407 sec)
# INFO:tensorflow:global_step/sec: 229.62
# INFO:tensorflow:loss = 0.000837331, step = 30301 (0.436 sec)
# INFO:tensorflow:global_step/sec: 235.207
# INFO:tensorflow:loss = 0.00138102, step = 30401 (0.425 sec)
# INFO:tensorflow:global_step/sec: 234.841
# INFO:tensorflow:loss = 0.000929428, step = 30501 (0.426 sec)
# INFO:tensorflow:global_step/sec: 229.367
# INFO:tensorflow:loss = 0.00146183, step = 30601 (0.436 sec)
# INFO:tensorflow:global_step/sec: 195.218
# INFO:tensorflow:loss = 0.000773375, step = 30701 (0.513 sec)
# INFO:tensorflow:global_step/sec: 203.022
# INFO:tensorflow:loss = 0.00110586, step = 30801 (0.493 sec)
# INFO:tensorflow:global_step/sec: 220.083
# INFO:tensorflow:loss = 0.00121131, step = 30901 (0.456 sec)
# INFO:tensorflow:global_step/sec: 254.639
# INFO:tensorflow:loss = 0.00107659, step = 31001 (0.389 sec)
# INFO:tensorflow:global_step/sec: 213.667
# INFO:tensorflow:loss = 0.00138425, step = 31101 (0.469 sec)
# INFO:tensorflow:global_step/sec: 216.465
# INFO:tensorflow:loss = 0.000538949, step = 31201 (0.463 sec)
# INFO:tensorflow:global_step/sec: 180.388
# INFO:tensorflow:loss = 0.000428765, step = 31301 (0.553 sec)
# INFO:tensorflow:global_step/sec: 203.596
# INFO:tensorflow:loss = 0.000609493, step = 31401 (0.495 sec)
# INFO:tensorflow:global_step/sec: 163.904
# INFO:tensorflow:loss = 0.00025601, step = 31501 (0.605 sec)
# INFO:tensorflow:global_step/sec: 169.76
# INFO:tensorflow:loss = 8.65842e-05, step = 31601 (0.593 sec)
# INFO:tensorflow:global_step/sec: 183.111
# INFO:tensorflow:loss = 0.000604256, step = 31701 (0.546 sec)
# INFO:tensorflow:global_step/sec: 165.83
# INFO:tensorflow:loss = 9.59904e-05, step = 31801 (0.601 sec)
# INFO:tensorflow:global_step/sec: 202.386
# INFO:tensorflow:loss = 0.00079322, step = 31901 (0.495 sec)
# INFO:tensorflow:global_step/sec: 205.477
# INFO:tensorflow:loss = 0.000262161, step = 32001 (0.486 sec)
# INFO:tensorflow:global_step/sec: 212.945
# INFO:tensorflow:loss = 0.000368648, step = 32101 (0.470 sec)
# INFO:tensorflow:global_step/sec: 218.046
# INFO:tensorflow:loss = 0.00113988, step = 32201 (0.460 sec)
# INFO:tensorflow:global_step/sec: 219.081
# INFO:tensorflow:loss = 0.00038782, step = 32301 (0.457 sec)
# INFO:tensorflow:global_step/sec: 225.33
# INFO:tensorflow:loss = 0.000149349, step = 32401 (0.443 sec)
# INFO:tensorflow:global_step/sec: 230.02
# INFO:tensorflow:loss = 0.000642526, step = 32501 (0.434 sec)
# INFO:tensorflow:global_step/sec: 221.789
# INFO:tensorflow:loss = 0.000118947, step = 32601 (0.452 sec)
# INFO:tensorflow:global_step/sec: 222.119
# INFO:tensorflow:loss = 0.00136909, step = 32701 (0.449 sec)
# INFO:tensorflow:global_step/sec: 235.888
# INFO:tensorflow:loss = 0.00105548, step = 32801 (0.424 sec)
# INFO:tensorflow:global_step/sec: 239.72
# INFO:tensorflow:loss = 0.0003802, step = 32901 (0.419 sec)
# INFO:tensorflow:global_step/sec: 193.065
# INFO:tensorflow:loss = 0.000608995, step = 33001 (0.518 sec)
# INFO:tensorflow:global_step/sec: 187.713
# INFO:tensorflow:loss = 0.0019107, step = 33101 (0.530 sec)
# INFO:tensorflow:global_step/sec: 212.309
# INFO:tensorflow:loss = 0.000916178, step = 33201 (0.471 sec)
# INFO:tensorflow:global_step/sec: 201.921
# INFO:tensorflow:loss = 0.000244862, step = 33301 (0.496 sec)
# INFO:tensorflow:global_step/sec: 225.665
# INFO:tensorflow:loss = 0.00129239, step = 33401 (0.442 sec)
# INFO:tensorflow:global_step/sec: 211.427
# INFO:tensorflow:loss = 0.000242947, step = 33501 (0.473 sec)
# INFO:tensorflow:global_step/sec: 171.192
# INFO:tensorflow:loss = 0.000883703, step = 33601 (0.585 sec)
# INFO:tensorflow:global_step/sec: 177.455
# INFO:tensorflow:loss = 0.000904791, step = 33701 (0.562 sec)
# INFO:tensorflow:global_step/sec: 188.139
# INFO:tensorflow:loss = 0.00107614, step = 33801 (0.538 sec)
# INFO:tensorflow:global_step/sec: 191.664
# INFO:tensorflow:loss = 0.00107961, step = 33901 (0.516 sec)
# INFO:tensorflow:global_step/sec: 206.916
# INFO:tensorflow:loss = 0.000613074, step = 34001 (0.484 sec)
# INFO:tensorflow:global_step/sec: 207.09
# INFO:tensorflow:loss = 0.00085227, step = 34101 (0.482 sec)
# INFO:tensorflow:global_step/sec: 252.557
# INFO:tensorflow:loss = 0.00112095, step = 34201 (0.396 sec)
# INFO:tensorflow:global_step/sec: 251.58
# INFO:tensorflow:loss = 0.000104322, step = 34301 (0.398 sec)
# INFO:tensorflow:global_step/sec: 254.595
# INFO:tensorflow:loss = 0.000506521, step = 34401 (0.393 sec)
# INFO:tensorflow:global_step/sec: 250.922
# INFO:tensorflow:loss = 0.000799231, step = 34501 (0.399 sec)
# INFO:tensorflow:global_step/sec: 256.51
# INFO:tensorflow:loss = 0.000381998, step = 34601 (0.390 sec)
# INFO:tensorflow:global_step/sec: 244.307
# INFO:tensorflow:loss = 0.00197285, step = 34701 (0.409 sec)
# INFO:tensorflow:global_step/sec: 243.426
# INFO:tensorflow:loss = 0.00050132, step = 34801 (0.411 sec)
# INFO:tensorflow:global_step/sec: 246.965
# INFO:tensorflow:loss = 0.000430059, step = 34901 (0.405 sec)
# INFO:tensorflow:global_step/sec: 219.576
# INFO:tensorflow:loss = 0.000284109, step = 35001 (0.456 sec)
# INFO:tensorflow:global_step/sec: 241.496
# INFO:tensorflow:loss = 0.0012278, step = 35101 (0.414 sec)
# INFO:tensorflow:global_step/sec: 229.156
# INFO:tensorflow:loss = 0.000280491, step = 35201 (0.437 sec)
# INFO:tensorflow:global_step/sec: 229.097
# INFO:tensorflow:loss = 0.000161269, step = 35301 (0.438 sec)
# INFO:tensorflow:global_step/sec: 239.034
# INFO:tensorflow:loss = 0.00105551, step = 35401 (0.417 sec)
# INFO:tensorflow:global_step/sec: 259.151
# INFO:tensorflow:loss = 0.000203097, step = 35501 (0.386 sec)
# INFO:tensorflow:global_step/sec: 238.184
# INFO:tensorflow:loss = 0.000242335, step = 35601 (0.420 sec)
# INFO:tensorflow:global_step/sec: 227.901
# INFO:tensorflow:loss = 0.00086094, step = 35701 (0.439 sec)
# INFO:tensorflow:global_step/sec: 240.275
# INFO:tensorflow:loss = 0.000918586, step = 35801 (0.417 sec)
# INFO:tensorflow:global_step/sec: 204.387
# INFO:tensorflow:loss = 0.000671677, step = 35901 (0.489 sec)
# INFO:tensorflow:global_step/sec: 189.233
# INFO:tensorflow:loss = 0.000370165, step = 36001 (0.531 sec)
# INFO:tensorflow:global_step/sec: 220.533
# INFO:tensorflow:loss = 0.00120145, step = 36101 (0.451 sec)
# INFO:tensorflow:global_step/sec: 202.773
# INFO:tensorflow:loss = 0.000768125, step = 36201 (0.495 sec)
# INFO:tensorflow:global_step/sec: 211.021
# INFO:tensorflow:loss = 0.000106661, step = 36301 (0.471 sec)
# INFO:tensorflow:global_step/sec: 212.07
# INFO:tensorflow:loss = 0.000681248, step = 36401 (0.472 sec)
# INFO:tensorflow:global_step/sec: 210.335
# INFO:tensorflow:loss = 0.000214154, step = 36501 (0.475 sec)
# INFO:tensorflow:global_step/sec: 224.219
# INFO:tensorflow:loss = 0.000239673, step = 36601 (0.446 sec)
# INFO:tensorflow:global_step/sec: 217.73
# INFO:tensorflow:loss = 0.000405055, step = 36701 (0.459 sec)
# INFO:tensorflow:global_step/sec: 222.976
# INFO:tensorflow:loss = 0.000852568, step = 36801 (0.449 sec)
# INFO:tensorflow:global_step/sec: 203.588
# INFO:tensorflow:loss = 0.000667005, step = 36901 (0.491 sec)
# INFO:tensorflow:global_step/sec: 173.319
# INFO:tensorflow:loss = 0.000488099, step = 37001 (0.579 sec)
# INFO:tensorflow:global_step/sec: 166.113
# INFO:tensorflow:loss = 0.000311534, step = 37101 (0.599 sec)
# INFO:tensorflow:global_step/sec: 204.167
# INFO:tensorflow:loss = 0.000358862, step = 37201 (0.490 sec)
# INFO:tensorflow:global_step/sec: 239.045
# INFO:tensorflow:loss = 0.000707558, step = 37301 (0.420 sec)
# INFO:tensorflow:global_step/sec: 236.859
# INFO:tensorflow:loss = 0.000318062, step = 37401 (0.420 sec)
# INFO:tensorflow:global_step/sec: 218.266
# INFO:tensorflow:loss = 0.000298998, step = 37501 (0.459 sec)
# INFO:tensorflow:global_step/sec: 205.789
# INFO:tensorflow:loss = 0.000414938, step = 37601 (0.489 sec)
# INFO:tensorflow:global_step/sec: 233.224
# INFO:tensorflow:loss = 0.000145852, step = 37701 (0.425 sec)
# INFO:tensorflow:global_step/sec: 238.363
# INFO:tensorflow:loss = 0.000346428, step = 37801 (0.420 sec)
# INFO:tensorflow:global_step/sec: 243.553
# INFO:tensorflow:loss = 0.0015781, step = 37901 (0.411 sec)
# INFO:tensorflow:global_step/sec: 236.012
# INFO:tensorflow:loss = 0.000307783, step = 38001 (0.424 sec)
# INFO:tensorflow:global_step/sec: 237.103
# INFO:tensorflow:loss = 0.00120952, step = 38101 (0.423 sec)
# INFO:tensorflow:global_step/sec: 233.137
# INFO:tensorflow:loss = 0.000719946, step = 38201 (0.427 sec)
# INFO:tensorflow:global_step/sec: 220.48
# INFO:tensorflow:loss = 9.19537e-05, step = 38301 (0.454 sec)
# INFO:tensorflow:global_step/sec: 206.561
# INFO:tensorflow:loss = 0.000204637, step = 38401 (0.485 sec)
# INFO:tensorflow:global_step/sec: 194.973
# INFO:tensorflow:loss = 0.000502236, step = 38501 (0.524 sec)
# INFO:tensorflow:global_step/sec: 232.656
# INFO:tensorflow:loss = 0.000743682, step = 38601 (0.418 sec)
# INFO:tensorflow:global_step/sec: 239.842
# INFO:tensorflow:loss = 0.000451052, step = 38701 (0.417 sec)
# INFO:tensorflow:global_step/sec: 244.237
# INFO:tensorflow:loss = 0.000246905, step = 38801 (0.411 sec)
# INFO:tensorflow:global_step/sec: 244.069
# INFO:tensorflow:loss = 0.00129647, step = 38901 (0.408 sec)
# INFO:tensorflow:global_step/sec: 239.72
# INFO:tensorflow:loss = 0.000217024, step = 39001 (0.417 sec)
# INFO:tensorflow:global_step/sec: 238.233
# INFO:tensorflow:loss = 0.000741188, step = 39101 (0.420 sec)
# INFO:tensorflow:global_step/sec: 241.714
# INFO:tensorflow:loss = 0.000570652, step = 39201 (0.414 sec)
# INFO:tensorflow:global_step/sec: 242.198
# INFO:tensorflow:loss = 0.000307514, step = 39301 (0.412 sec)
# INFO:tensorflow:global_step/sec: 236.359
# INFO:tensorflow:loss = 0.00066551, step = 39401 (0.423 sec)
# INFO:tensorflow:global_step/sec: 238.833
# INFO:tensorflow:loss = 0.000248625, step = 39501 (0.419 sec)
# INFO:tensorflow:global_step/sec: 243.509
# INFO:tensorflow:loss = 0.000750375, step = 39601 (0.410 sec)
# INFO:tensorflow:global_step/sec: 245.914
# INFO:tensorflow:loss = 0.000224784, step = 39701 (0.407 sec)
# INFO:tensorflow:global_step/sec: 242.504
# INFO:tensorflow:loss = 0.00105966, step = 39801 (0.413 sec)
# INFO:tensorflow:global_step/sec: 247.628
# INFO:tensorflow:loss = 0.00136582, step = 39901 (0.404 sec)
# INFO:tensorflow:Saving checkpoints for 40000 into /var/folders/59/0pbnsns93t5cgn8b5n2kpxt00000gn/T/tmpc_4b1195/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.00045437.
# SKCompat()

# %%
from sklearn.metrics import accuracy_score

y_pred = dnn_clf.predict(X_test)
accuracy_score(y_test, y_pred['classes'])
# Out:
# INFO:tensorflow:Restoring parameters from /var/folders/59/0pbnsns93t5cgn8b5n2kpxt00000gn/T/tmpc_4b1195/model.ckpt-40000
# 0.98240000000000005

# %%
from sklearn.metrics import log_loss

y_pred_proba = y_pred['probabilities']
log_loss(y_test, y_pred_proba)
# Out:
# 0.071563045266568537

# %% [markdown]
# ## Using plain TensorFlow

# %%
import tensorflow as tf
import numpy as np

n_inputs = 28*28  # MNIST
n_hidden1 = 300
n_hidden2 = 100
n_outputs = 10

# %%
def reset_graph(seed=42):
    tf.reset_default_graph()
    tf.set_random_seed(seed)
    np.random.seed(seed)
    
reset_graph()

X = tf.placeholder(tf.float32, shape=(None, n_inputs), name="X")
y = tf.placeholder(tf.int64, shape=(None), name="y")

# %%
def neuron_layer(X, n_neurons, name, activation=None):
    with tf.name_scope(name):
        n_inputs = int(X.get_shape()[1])
        stddev = 2 / np.sqrt(n_inputs)
        init = tf.truncated_normal((n_inputs, n_neurons), stddev=stddev)
        W = tf.Variable(init, name="kernel")
        b = tf.Variable(tf.zeros([n_neurons]), name="bias")
        Z = tf.matmul(X, W) + b
        if activation is not None:
            return activation(Z)
        else:
            return Z

# %%
with tf.name_scope("dnn"):
    hidden1 = neuron_layer(X, n_hidden1, name="hidden1",
                           activation=tf.nn.relu)
    hidden2 = neuron_layer(hidden1, n_hidden2, name="hidden2",
                           activation=tf.nn.relu)
    logits = neuron_layer(hidden2, n_outputs, name="outputs")

# %%
with tf.name_scope("loss"):
    xentropy = tf.nn.sparse_softmax_cross_entropy_with_logits(labels=y,
                                                              logits=logits)
    loss = tf.reduce_mean(xentropy, name="loss")

# %%
learning_rate = 0.01

with tf.name_scope("train"):
    optimizer = tf.train.GradientDescentOptimizer(learning_rate)
    training_op = optimizer.minimize(loss)

# %%
with tf.name_scope("eval"):
    correct = tf.nn.in_top_k(logits, y, 1)
    accuracy = tf.reduce_mean(tf.cast(correct, tf.float32))

# %%
init = tf.global_variables_initializer()
saver = tf.train.Saver()

# %%
n_epochs = 40
batch_size = 50

# %%
with tf.Session() as sess:
    init.run()
    for epoch in range(n_epochs):
        for iteration in range(mnist.train.num_examples // batch_size):
            X_batch, y_batch = mnist.train.next_batch(batch_size)
            sess.run(training_op, feed_dict={X: X_batch, y: y_batch})
        acc_train = accuracy.eval(feed_dict={X: X_batch, y: y_batch})
        acc_test = accuracy.eval(feed_dict={X: mnist.test.images,
                                            y: mnist.test.labels})
        print(epoch, "Train accuracy:", acc_train, "Test accuracy:", acc_test)

    save_path = saver.save(sess, "./my_model_final.ckpt")
# Out:
# 0 Train accuracy: 0.9 Test accuracy: 0.9128
# 1 Train accuracy: 0.94 Test accuracy: 0.9291
# 2 Train accuracy: 0.92 Test accuracy: 0.9398
# 3 Train accuracy: 0.96 Test accuracy: 0.945
# 4 Train accuracy: 0.92 Test accuracy: 0.9513
# 5 Train accuracy: 0.94 Test accuracy: 0.9543
# 6 Train accuracy: 0.98 Test accuracy: 0.9556
# 7 Train accuracy: 0.96 Test accuracy: 0.9593
# 8 Train accuracy: 0.92 Test accuracy: 0.9625
# 9 Train accuracy: 0.96 Test accuracy: 0.9645
# 10 Train accuracy: 0.98 Test accuracy: 0.9651
# 11 Train accuracy: 0.94 Test accuracy: 0.967
# 12 Train accuracy: 1.0 Test accuracy: 0.9691
# 13 Train accuracy: 0.94 Test accuracy: 0.9684
# 14 Train accuracy: 1.0 Test accuracy: 0.9697
# 15 Train accuracy: 1.0 Test accuracy: 0.9714
# 16 Train accuracy: 1.0 Test accuracy: 0.9714
# 17 Train accuracy: 0.98 Test accuracy: 0.9715
# 18 Train accuracy: 1.0 Test accuracy: 0.973
# 19 Train accuracy: 1.0 Test accuracy: 0.973
# 20 Train accuracy: 0.98 Test accuracy: 0.9736
# 21 Train accuracy: 1.0 Test accuracy: 0.974
# 22 Train accuracy: 1.0 Test accuracy: 0.9745
# 23 Train accuracy: 1.0 Test accuracy: 0.9749
# 24 Train accuracy: 1.0 Test accuracy: 0.975
# 25 Train accuracy: 1.0 Test accuracy: 0.9756
# 26 Train accuracy: 1.0 Test accuracy: 0.975
# 27 Train accuracy: 1.0 Test accuracy: 0.9759
# 28 Train accuracy: 0.98 Test accuracy: 0.976
# 29 Train accuracy: 1.0 Test accuracy: 0.9768
# 30 Train accuracy: 1.0 Test accuracy: 0.9766
# 31 Train accuracy: 1.0 Test accuracy: 0.9769
# 32 Train accuracy: 0.98 Test accuracy: 0.9768
# 33 Train accuracy: 0.98 Test accuracy: 0.9764
# 34 Train accuracy: 0.98 Test accuracy: 0.9788
# 35 Train accuracy: 0.98 Test accuracy: 0.9776
# 36 Train accuracy: 0.98 Test accuracy: 0.977
# 37 Train accuracy: 1.0 Test accuracy: 0.9785
# 38 Train accuracy: 1.0 Test accuracy: 0.9784
# 39 Train accuracy: 1.0 Test accuracy: 0.9782

# %% [markdown]
# ## Fetch final models

# %%
with tf.Session() as sess:
    saver.restore(sess, "./my_model_final.ckpt") # or better, use save_path
    X_new_scaled = mnist.test.images[:20]
    Z = logits.eval(feed_dict={X: X_new_scaled})
    y_pred = np.argmax(Z, axis=1)
# Out:
# INFO:tensorflow:Restoring parameters from ./my_model_final.ckpt

# %%
print("Predicted classes:", y_pred)
print("Actual classes:   ", mnist.test.labels[:20])
# Out:
# Predicted classes: [7 2 1 0 4 1 4 9 6 9 0 6 9 0 1 5 9 7 3 4]
# Actual classes:    [7 2 1 0 4 1 4 9 5 9 0 6 9 0 1 5 9 7 3 4]

# %%
from IPython.display import clear_output, Image, display, HTML

def strip_consts(graph_def, max_const_size=32):
    """Strip large constant values from graph_def."""
    strip_def = tf.GraphDef()
    for n0 in graph_def.node:
        n = strip_def.node.add() 
        n.MergeFrom(n0)
        if n.op == 'Const':
            tensor = n.attr['value'].tensor
            size = len(tensor.tensor_content)
            if size > max_const_size:
                tensor.tensor_content = b"<stripped %d bytes>"%size
    return strip_def

def show_graph(graph_def, max_const_size=32):
    """Visualize TensorFlow graph."""
    if hasattr(graph_def, 'as_graph_def'):
        graph_def = graph_def.as_graph_def()
    strip_def = strip_consts(graph_def, max_const_size=max_const_size)
    code = """
        <script>
          function load() {{
            document.getElementById("{id}").pbtxt = {data};
          }}
        </script>
        <link rel="import" href="https://tensorboard.appspot.com/tf-graph-basic.build.html" onload=load()>
        <div style="height:600px">
          <tf-graph-basic id="{id}"></tf-graph-basic>
        </div>
    """.format(data=repr(str(strip_def)), id='graph'+str(np.random.rand()))

    iframe = """
        <iframe seamless style="width:1200px;height:620px;border:0" srcdoc="{}"></iframe>
    """.format(code.replace('"', '&quot;'))
    display(HTML(iframe))

# %%
show_graph(tf.get_default_graph())
# Out:
#         <iframe seamless style="width:1200px;height:620px;border:0" srcdoc="
#         <script>
#           function load() {
#             document.getElementById(&quot;graph0.2851015593374667&quot;).pbtxt = 'node {\n  name: &quot;X&quot;\n  op: &quot;Placeholder&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;shape&quot;\n    value {\n      shape {\n        dim {\n          size: -1\n        }\n        dim {\n          size: 784\n        }\n      }\n    }\n  }\n}\nnode {\n  name: &quot;y&quot;\n  op: &quot;Placeholder&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_INT64\n    }\n  }\n  attr {\n    key: &quot;shape&quot;\n    value {\n      shape {\n        unknown_rank: true\n      }\n    }\n  }\n}\nnode {\n  name: &quot;dnn/hidden1/truncated_normal/shape&quot;\n  op: &quot;Const&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_INT32\n    }\n  }\n  attr {\n    key: &quot;value&quot;\n    value {\n      tensor {\n        dtype: DT_INT32\n        tensor_shape {\n          dim {\n            size: 2\n          }\n        }\n        tensor_content: &quot;\\020\\003\\000\\000,\\001\\000\\000&quot;\n      }\n    }\n  }\n}\nnode {\n  name: &quot;dnn/hidden1/truncated_normal/mean&quot;\n  op: &quot;Const&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;value&quot;\n    value {\n      tensor {\n        dtype: DT_FLOAT\n        tensor_shape {\n        }\n        float_val: 0.0\n      }\n    }\n  }\n}\nnode {\n  name: &quot;dnn/hidden1/truncated_normal/stddev&quot;\n  op: &quot;Const&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;value&quot;\n    value {\n      tensor {\n        dtype: DT_FLOAT\n        tensor_shape {\n        }\n        float_val: 0.0714285746216774\n      }\n    }\n  }\n}\nnode {\n  name: &quot;dnn/hidden1/truncated_normal/TruncatedNormal&quot;\n  op: &quot;TruncatedNormal&quot;\n  input: &quot;dnn/hidden1/truncated_normal/shape&quot;\n  attr {\n    key: &quot;T&quot;\n    value {\n      type: DT_INT32\n    }\n  }\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;seed&quot;\n    value {\n      i: 42\n    }\n  }\n  attr {\n    key: &quot;seed2&quot;\n    value {\n      i: 5\n    }\n  }\n}\nnode {\n  name: &quot;dnn/hidden1/truncated_normal/mul&quot;\n  op: &quot;Mul&quot;\n  input: &quot;dnn/hidden1/truncated_normal/TruncatedNormal&quot;\n  input: &quot;dnn/hidden1/truncated_normal/stddev&quot;\n  attr {\n    key: &quot;T&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n}\nnode {\n  name: &quot;dnn/hidden1/truncated_normal&quot;\n  op: &quot;Add&quot;\n  input: &quot;dnn/hidden1/truncated_normal/mul&quot;\n  input: &quot;dnn/hidden1/truncated_normal/mean&quot;\n  attr {\n    key: &quot;T&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n}\nnode {\n  name: &quot;dnn/hidden1/kernel&quot;\n  op: &quot;VariableV2&quot;\n  attr {\n    key: &quot;container&quot;\n    value {\n      s: &quot;&quot;\n    }\n  }\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;shape&quot;\n    value {\n      shape {\n        dim {\n          size: 784\n        }\n        dim {\n          size: 300\n        }\n      }\n    }\n  }\n  attr {\n    key: &quot;shared_name&quot;\n    value {\n      s: &quot;&quot;\n    }\n  }\n}\nnode {\n  name: &quot;dnn/hidden1/kernel/Assign&quot;\n  op: &quot;Assign&quot;\n  input: &quot;dnn/hidden1/kernel&quot;\n  input: &quot;dnn/hidden1/truncated_normal&quot;\n  attr {\n    key: &quot;T&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;_class&quot;\n    value {\n      list {\n        s: &quot;loc:@dnn/hidden1/kernel&quot;\n      }\n    }\n  }\n  attr {\n    key: &quot;use_locking&quot;\n    value {\n      b: true\n    }\n  }\n  attr {\n    key: &quot;validate_shape&quot;\n    value {\n      b: true\n    }\n  }\n}\nnode {\n  nam ...

# %% [markdown]
# ## Using dense() instead of neuron_layer()

# %%
n_inputs = 28*28  # MNIST
n_hidden1 = 300
n_hidden2 = 100
n_outputs = 10

# %%
reset_graph()

X = tf.placeholder(tf.float32, shape=(None, n_inputs), name="X")
y = tf.placeholder(tf.int64, shape=(None), name="y")

# %%
with tf.name_scope("dnn"):
    hidden1 = tf.layers.dense(X, n_hidden1, name="hidden1",
                              activation=tf.nn.relu)
    hidden2 = tf.layers.dense(hidden1, n_hidden2, name="hidden2",
                              activation=tf.nn.relu)
    logits = tf.layers.dense(hidden2, n_outputs, name="outputs")

# %%
with tf.name_scope("loss"):
    xentropy = tf.nn.sparse_softmax_cross_entropy_with_logits(labels=y, logits=logits)
    loss = tf.reduce_mean(xentropy, name="loss")

# %%
learning_rate = 0.01

with tf.name_scope("train"):
    optimizer = tf.train.GradientDescentOptimizer(learning_rate)
    training_op = optimizer.minimize(loss)

# %%
with tf.name_scope("eval"):
    correct = tf.nn.in_top_k(logits, y, 1)
    accuracy = tf.reduce_mean(tf.cast(correct, tf.float32))

# %%
init = tf.global_variables_initializer()
saver = tf.train.Saver()

# %%
n_epochs = 20
n_batches = 50

with tf.Session() as sess:
    init.run()
    for epoch in range(n_epochs):
        for iteration in range(mnist.train.num_examples // batch_size):
            X_batch, y_batch = mnist.train.next_batch(batch_size)
            sess.run(training_op, feed_dict={X: X_batch, y: y_batch})
        acc_train = accuracy.eval(feed_dict={X: X_batch, y: y_batch})
        acc_test = accuracy.eval(feed_dict={X: mnist.test.images, y: mnist.test.labels})
        print(epoch, "Train accuracy:", acc_train, "Test accuracy:", acc_test)

    save_path = saver.save(sess, "./my_model_final.ckpt")
# Out:
# 0 Train accuracy: 0.9 Test accuracy: 0.9053
# 1 Train accuracy: 0.88 Test accuracy: 0.9206
# 2 Train accuracy: 0.94 Test accuracy: 0.9301
# 3 Train accuracy: 0.94 Test accuracy: 0.9397
# 4 Train accuracy: 0.92 Test accuracy: 0.945
# 5 Train accuracy: 0.94 Test accuracy: 0.9476
# 6 Train accuracy: 0.92 Test accuracy: 0.9514
# 7 Train accuracy: 0.98 Test accuracy: 0.9547
# 8 Train accuracy: 0.96 Test accuracy: 0.9569
# 9 Train accuracy: 0.94 Test accuracy: 0.9605
# 10 Train accuracy: 0.92 Test accuracy: 0.962
# 11 Train accuracy: 0.96 Test accuracy: 0.9631
# 12 Train accuracy: 1.0 Test accuracy: 0.966
# 13 Train accuracy: 0.94 Test accuracy: 0.9656
# 14 Train accuracy: 1.0 Test accuracy: 0.967
# 15 Train accuracy: 0.94 Test accuracy: 0.9682
# 16 Train accuracy: 0.96 Test accuracy: 0.97
# 17 Train accuracy: 0.98 Test accuracy: 0.9695
# 18 Train accuracy: 1.0 Test accuracy: 0.97
# 19 Train accuracy: 1.0 Test accuracy: 0.9708

# %%
show_graph(tf.get_default_graph())
# Out:
#         <iframe seamless style="width:1200px;height:620px;border:0" srcdoc="
#         <script>
#           function load() {
#             document.getElementById(&quot;graph0.7224827313584268&quot;).pbtxt = 'node {\n  name: &quot;X&quot;\n  op: &quot;Placeholder&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;shape&quot;\n    value {\n      shape {\n        dim {\n          size: -1\n        }\n        dim {\n          size: 784\n        }\n      }\n    }\n  }\n}\nnode {\n  name: &quot;y&quot;\n  op: &quot;Placeholder&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_INT64\n    }\n  }\n  attr {\n    key: &quot;shape&quot;\n    value {\n      shape {\n        unknown_rank: true\n      }\n    }\n  }\n}\nnode {\n  name: &quot;hidden1/kernel/Initializer/random_uniform/shape&quot;\n  op: &quot;Const&quot;\n  attr {\n    key: &quot;_class&quot;\n    value {\n      list {\n        s: &quot;loc:@hidden1/kernel&quot;\n      }\n    }\n  }\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_INT32\n    }\n  }\n  attr {\n    key: &quot;value&quot;\n    value {\n      tensor {\n        dtype: DT_INT32\n        tensor_shape {\n          dim {\n            size: 2\n          }\n        }\n        tensor_content: &quot;\\020\\003\\000\\000,\\001\\000\\000&quot;\n      }\n    }\n  }\n}\nnode {\n  name: &quot;hidden1/kernel/Initializer/random_uniform/min&quot;\n  op: &quot;Const&quot;\n  attr {\n    key: &quot;_class&quot;\n    value {\n      list {\n        s: &quot;loc:@hidden1/kernel&quot;\n      }\n    }\n  }\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;value&quot;\n    value {\n      tensor {\n        dtype: DT_FLOAT\n        tensor_shape {\n        }\n        float_val: -0.07439795136451721\n      }\n    }\n  }\n}\nnode {\n  name: &quot;hidden1/kernel/Initializer/random_uniform/max&quot;\n  op: &quot;Const&quot;\n  attr {\n    key: &quot;_class&quot;\n    value {\n      list {\n        s: &quot;loc:@hidden1/kernel&quot;\n      }\n    }\n  }\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;value&quot;\n    value {\n      tensor {\n        dtype: DT_FLOAT\n        tensor_shape {\n        }\n        float_val: 0.07439795136451721\n      }\n    }\n  }\n}\nnode {\n  name: &quot;hidden1/kernel/Initializer/random_uniform/RandomUniform&quot;\n  op: &quot;RandomUniform&quot;\n  input: &quot;hidden1/kernel/Initializer/random_uniform/shape&quot;\n  attr {\n    key: &quot;T&quot;\n    value {\n      type: DT_INT32\n    }\n  }\n  attr {\n    key: &quot;_class&quot;\n    value {\n      list {\n        s: &quot;loc:@hidden1/kernel&quot;\n      }\n    }\n  }\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;seed&quot;\n    value {\n      i: 42\n    }\n  }\n  attr {\n    key: &quot;seed2&quot;\n    value {\n      i: 5\n    }\n  }\n}\nnode {\n  name: &quot;hidden1/kernel/Initializer/random_uniform/sub&quot;\n  op: &quot;Sub&quot;\n  input: &quot;hidden1/kernel/Initializer/random_uniform/max&quot;\n  input: &quot;hidden1/kernel/Initializer/random_uniform/min&quot;\n  attr {\n    key: &quot;T&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;_class&quot;\n    value {\n      list {\n        s: &quot;loc:@hidden1/kernel&quot;\n      }\n    }\n  }\n}\nnode {\n  name: &quot;hidden1/kernel/Initializer/random_uniform/mul&quot;\n  op: &quot;Mul&quot;\n  input: &quot;hidden1/kernel/Initializer/random_uniform/RandomUniform&quot;\n  input: &quot;hidden1/kernel/Initializer/random_uniform/sub&quot;\n  attr {\n    key: &quot;T&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;_class&quot;\n    value {\n      list {\n        s: &quot;loc:@hidden1/kernel&quot;\n      }\n    }\n  }\n}\nnode {\n  name: &quot;hidden1/kernel/Initializer/random_uniform&quot;\n  op: &quot;Add&quot;\n  input: &quot;hidden1/kernel/Initializer/random_uniform/mul&quot;\n  inpu ...
